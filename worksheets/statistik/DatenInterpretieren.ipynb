# %% [markdown]
# # Daten interpretieren
#
# Diagramme erstellen kannst du bereits. Jetzt geht es um den nächsten Schritt: Daten *lesen* und verstehen, was sie bedeuten und welche Handlungen sich daraus ableiten lassen.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     Führe den folgenden Code-Block aus, um die Hilfsfunktionen im Hintergrund zu laden.
# </div>

# %%
import sys
sys.path.append("../../../Informatik-Notebooks/code/")
from SetupDatenInterpretieren import *

import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# ## Aufgabe 1: Lernverhalten interpretieren
#
# Der folgende Plot zeigt die Klausurergebnisse einer Schulklasse über mehrere Klausuren. Auf der x-Achse ist die Lernzeit (in Stunden) vor der Klausur abgetragen, auf der y-Achse die erreichte Punktzahl in Prozent.
#
# Neben den allgemeinen Datenpunkten (blau) sind die Ergebnisse von drei Personen farbig hervorgehoben.
#
# <div class="alert alert-block alert-warning">
#     Führe den folgenden Code-Block aus.
# </div>

# %%
zeige_lernplot()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <ol>
#         <li>Beschreibe, was dir auffällt wenn du alle Datenpunkte betrachtest.</li>
#         <li>Beschreibe jede der drei Personen anhand ihrer Datenpunkte im Plot. Was fällt dir auf?</li>
#         <li>Formuliere für jede Person eine konkrete Handlungsempfehlung: Was würdest du ihr raten?</li>
#     </ol>
# </div>

# %% [markdown]
# ## Aufgabe 2: Notenverteilung vergleichen
#
# Zwei Klassen haben dieselbe Mathematikarbeit geschrieben. Die Funktion `get_notendaten()` liefert zwei Listen zurück: `klasse1` und `klasse2` jeweils mit den Einzelnoten aller Schüler:innen als ganze Zahlen von 1 bis 6. Mit `statistics.mean(klasse1)` kannst du den Durchschnitt einer Klasse berechnen.
#
# <div class="alert alert-block alert-warning">
#     Lade die Noten mit <code>klasse1, klasse2 = get_notendaten()</code> und berechne den Mittelwert beider Klassen. Was fällt dir auf?
# </div>

# %%
klasse1, klasse2 = get_notendaten()

# Berechne hier den Mittelwert beider Klassen. Nutze print() um die Werte anzuzeigen:

# %% [markdown]
# Der Mittelwert ist also gleich, aber beschreibt das wirklich, wie sich die beiden Klassen unterscheiden?
#
# Um tiefer in die Daten zu schauen, erstelle ein Balkendiagramm der Notenverteilung für jede Klasse. Die folgende Zeile zählt, wie viele Schüler:innen jede Note erhalten haben:
#
# ```python
# anzahl = [klasse.count(i) for i in [1, 2, 3, 4, 5, 6]]
# ```
#
# Zwei Diagramme nebeneinander erstellst du mit `plt.subplots(1, 2, figsize=(12, 4))`.
#
# <div class="alert alert-block alert-warning">
#     Erstelle für jede Klasse ein Balkendiagramm der Notenverteilung. Welche Unterschiede siehst du obwohl der Mittelwert gleich ist?
# </div>

# %%
noten = [1, 2, 3, 4, 5, 6]
anzahl_klasse1 = [klasse1.count(i) for i in noten]
anzahl_klasse2 = [klasse2.count(i) for i in noten]

fig, achsen = plt.subplots(1, 2, figsize=(12, 4))

# Erstelle hier die Balkendiagramme:
# achsen[0].bar(...)  →  Klasse 1
# achsen[1].bar(...)  →  Klasse 2
# Vergiss Titel und Achsenbeschriftungen nicht!

plt.tight_layout()
plt.show()
